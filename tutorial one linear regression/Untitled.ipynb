# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
    # Fixed typo: 'pylot' -> 'pyplot'
from sklearn import linear_model

# %%
# Then read the CSV file
df = pd.read_csv("area_price_data.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel("area(sqr ft)")
plt.ylabel("price(US$)")
plt.scatter(df.area, df.price, color="red", marker="+")

# %%
reg= linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalise=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 reg= linear_model.LinearRegression()
#       2 reg.fit(df[['area']],df.price)
# ----> 3 LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalise=False)
#
# NameError: name 'LinearRegression' is not defined
